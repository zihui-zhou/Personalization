# %%
import pandas as pd
import numpy as np

# %%
user = pd.read_csv('Organized_dataset/cleaned/user_cleaned.csv')

# %%
user.head()
# Out:
#          yelping_since  useful  compliment_photos  compliment_list  \
# 0  2013-10-08 23:11:33      84                  0                0
# 1  2013-02-21 22:29:06      48                  0                0
# 2  2013-10-04 00:16:10      28                  0                0
# 3  2014-05-22 15:57:30      30                  0                0
# 4  2013-10-23 07:02:50    1114                  5                1
#
#    compliment_funny  compliment_plain  review_count  \
# 0                 1                 1            95
# 1                 1                 0            33
# 2                 0                 0            16
# 3                 0                 2            17
# 4                80                57           361
#
#                                              friends  fans  compliment_note  \
# 0  c78V-rj8NQcQjOI8KP3UEA, alRMgPcngYSCJ5naFRBz5g...     5                1
# 1  kEBTgDvFX754S68FllfCaA, aB2DynOxNOJK9st2ZeGTPg...     4                0
# ...

# %%
user.shape
# Out:
# (818922, 22)

# %%
len(user['user_id'].unique())
# Out:
# 818922

# %%
business = pd.read_csv('Organized_dataset/cleaned/business_cleaned.csv')

# %%
business.head()
# Out:
#                                              address  \
# 0                               30 Eglinton Avenue W
# 1                          10110 Johnston Rd, Ste 15
# 2                      15655 W Roosevelt St, Ste 237
# 3                     4209 Stuart Andrew Blvd, Ste F
# 4  Credit Valley Town Plaza, F2 - 6045 Creditview Rd
#
#                                           attributes             business_id  \
# 0  {'RestaurantsReservations': 'True', 'GoodForMe...  QXAEGFB4oINsVuTFxEYKFQ
# 1  {'GoodForKids': 'True', 'NoiseLevel': "u'avera...  gnKjwL_1w79qoiV3IC_xQQ
# 2                                                NaN  xvX2CttrVhyG2z1dFg_0xw
# 3  {'BusinessAcceptsBitcoin': 'False', 'ByAppoint...  HhyxOkGAM07SRYtlQ4wMFQ
# 4  {'BusinessParking': "{'garage': False, 'street...  68dUKd8_8liJ7in4aWOSEA
#
#                                           categories         city  \
# 0  Specialty Food, Restaurants, Dim Sum, Imported...  Mississauga
# ...

# %%
business['state'].nunique()
# Out:
# 36

# %%
business.shape
# Out:
# (158525, 14)

# %%
# the number of business remains in the dataset
len(business['business_id'].unique())
# Out:
# 158525

# %%
review = pd.read_csv('Organized_dataset/cleaned/review_cleaned.csv')
# Out:
# /Users/zhouzihui/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
review.head()
# Out:
#   funny useful               review_id  \
# 0     0      0  GJXCdrto3ASJOqKeVWPi6Q
# 1     0      3  2TzJjDVDEuAW6MR5Vuc1ug
# 2     4      5  G7XHMxG0bx9oBJNECG4IFg
# 3     0      0  svK3nBU7Rk8VfGorlrN52A
# 4     0      0  1wVA2-vQIuW_ClmXkDxqMQ
#
#                                                 text             business_id  \
# 0  I *adore* Travis at the Hard Rock's new Kelly ...  NZnhc2sEQy3RmzKTZnqtwQ
# 1  I have to say that this office really has it t...  WTqjgwHlXbSFevF32_DJVw
# 2  Tracy dessert had a big name in Hong Kong and ...  3fw2X5bZYeW9xCz_zGhOHg
# 3  You can't really find anything wrong with this...  YvrylyuWgbP90RgMqZQVnQ
# 4  Great lunch today. Staff was very helpful in a...  NyLYY8q1-H3hfsTwuwLPCg
#
#    stars                 date                 user_id  cool
# 0    5.0  2017-01-14 21:30:33  yXQM5uF2jS6es16SJzNHfg   0.0
# 1    5.0  2016-11-09 20:09:03  n6-Gk65cPZL6Uz8qRm3NYw   0.0
# 2    3.0  2016-05-07 01:21:02  jlu4CztcSxrKx56ba1a5AQ   5.0
# ...

# %%
review['stars'].min(), review['stars'].max()
# Out:
# (0.0, 5.0)

# %%
review.shape
# Out:
# (3148044, 9)

# %%
review_0 = pd.read_csv('Organized_dataset/review.csv')

# %%
review_0.head()
# Out:
#    funny  useful               review_id  \
# 0      1       6  Q1sbwvVQXV2734tPgoKj4Q
# 1      0       0  GJXCdrto3ASJOqKeVWPi6Q
# 2      0       3  2TzJjDVDEuAW6MR5Vuc1ug
# 3      0       0  yi0R0Ugj_xUx_Nek0-_Qig
# 4      0       7  11a8sVPMUFtaC7_ABRkmtw
#
#                                                 text             business_id  \
# 0  Total bill for this horrible service? Over $8G...  ujmEBvifdJM6h6RLv4wQIg
# 1  I *adore* Travis at the Hard Rock's new Kelly ...  NZnhc2sEQy3RmzKTZnqtwQ
# 2  I have to say that this office really has it t...  WTqjgwHlXbSFevF32_DJVw
# 3  Went in for a lunch. Steak sandwich was delici...  ikCg8xy5JIg_NGPx-MSIDA
# 4  Today was my second out of three sessions I ha...  b1b1eb3uo-w561D0ZfCEiQ
#
#    stars                 date                 user_id  cool
# 0    1.0  2013-05-07 04:34:36  hG7b0MtEbXx5QzbzE6C_VA     0
# 1    5.0  2017-01-14 21:30:33  yXQM5uF2jS6es16SJzNHfg     0
# 2    5.0  2016-11-09 20:09:03  n6-Gk65cPZL6Uz8qRm3NYw     0
# ...

# %%
review_0.shape
# Out:
# (6685900, 9)

# %%
user_0 = pd.read_csv('Organized_dataset/user.csv')
# Out:
# /Users/zhouzihui/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
user_0.head()
# Out:
#          yelping_since  useful  compliment_photos  compliment_list  \
# 0  2013-10-08 23:11:33      84                  0                0
# 1  2013-02-21 22:29:06      48                  0                0
# 2  2013-10-04 00:16:10      28                  0                0
# 3  2014-05-22 15:57:30      30                  0                0
# 4  2013-10-23 07:02:50    1114                  5                1
#
#    compliment_funny  compliment_plain  review_count  \
# 0                 1                 1            95
# 1                 1                 0            33
# 2                 0                 0            16
# 3                 0                 2            17
# 4                80                57           361
#
#                                              friends  fans  compliment_note  \
# 0  c78V-rj8NQcQjOI8KP3UEA, alRMgPcngYSCJ5naFRBz5g...     5                1
# 1  kEBTgDvFX754S68FllfCaA, aB2DynOxNOJK9st2ZeGTPg...     4                0
# ...

# %%
user_0.shape
# Out:
# (1637138, 22)
